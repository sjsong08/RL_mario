# %%
import gym
from gym import wrappers
import math, os, random
import numpy as np
import pickle
import matplotlib
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

from collections import namedtuple
from collections import deque
from itertools import count
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision.transforms as T

import ppaquette_gym_super_mario


checkpoint_dir = './checkpoints/'
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"
use_cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if use_cuda else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if use_cuda else torch.ByteTensor
print('CUDA!',use_cuda)

env = gym.make('ppaquette/SuperMarioBros-1-2-v0')
env = wrappers.Monitor(env, 'gym-results', force=True)

train = True
retrain = False



input_size = np.array([env.observation_space.shape[0], env.observation_space.shape[1], 15])
output_size = 13

dis = 0.9
REPLAY_MEMORY = 20000



def ddqn_replay_train(mainDQN, targetDQN, train_batch, l_rate):
    x_stack = np.empty(0).reshape(0, mainDQN.input_size[0]*mainDQN.input_size[1]*mainDQN.input_size[2])
    y_stack = np.empty(0).reshape(0, mainDQN.output_size)
    action_stack = np.empty(0).reshape(0, 60)
    for state, action_seq, action_next_seq, action , reward, next_state, done in train_batch:
        Q = mainDQN(state, action_seq)
        if done:
            Q[0, action] = reward
        else:
            Q[0, action] = reward + dis * targetDQN(next_state, action_next_seq).max(1)[0]
            
            
        if state is None:
            print("None State, ", action, ", ", reward, ", ", next_state,", ", done)
        else:
            y_stack = np.vstack([y_stack, Q.cpu().data.numpy()])
            x_stack = np.vstack([x_stack, state.reshape(-1, mainDQN.input_size[0]*mainDQN.input_size[1]*mainDQN.input_size[2])])
            action_stack = np.vstack([action_stack, np.reshape(action_seq, (-1, 60))])
    
    Qpred = mainDQN(x_stack, action_stack)
    loss = F.mse_loss(Qpred, Variable(torch.Tensor(y_stack)).type(FloatTensor))
    optm = optim.Adam(mainDQN.parameters())
    optm.zero_grad()
    loss.backward()
    optm.step()
    
    return loss


def bot_play(mainDQN, env=env):
    start = env.reset()
    reward_sum = 0
    while True:
        if state in None or state.size ==1:
            output = random.randint(0, output_size-1)
            action = OutputToAction3(output)
            print("random action:", output)
        else:
            output = np.argmax(mainDQN(state))
            action = OutputToAction3(output)
            print("predicted action:", output)
        for n in range(len(action)):
            state, reward, done, info = env.step(action[n])
            if done:
                break
        reward_sum += reward
        if done:
            print("Total score", reward_sum)
            break
            
def OutputToAction3(output):
    actions={ # A: jump , B: run
        '0' :[[0,0,0,0,0,0], 'Nope'],
        '1' :[[1,0,0,0,0,0], 'Up'],
        '2' :[[0,0,1,0,0,0], 'Down'],
        '3' :[[0,1,0,0,0,0], 'Left'],
        '4' :[[0,1,0,0,1,0], 'Left+jump'],
        '5' :[[0,1,0,0,0,1], 'Left+run'],
        '6' :[[0,1,0,0,1,1], 'Left+jump,run'],
        '7' :[[0,0,0,1,0,0], 'Right'],
        '8' :[[0,0,0,1,1,0], 'Right+jump'],
        '9' :[[0,0,0,1,0,1], 'Right+run'],
        '10':[[0,0,0,1,1,1], 'Right+jump,run'],
        '11':[[0,0,0,0,1,0], 'jump'],
        '12':[[0,0,0,0,1,1], 'jump,run']
    }
    return [np.array([actions[str(output)][0]]*2), actions[str(output)][1]]
    





class DQN(nn.Module):
    def __init__ (self, input_size, output_size):
        super(DQN, self).__init__()
        
        self.input_size = input_size
        self.output_size = output_size
        
        self.model1 = nn.Sequential(
            nn.Conv2d(15,64,3,1),
            nn.ReLU(),
            nn.Conv2d(64,64,3,2),
            nn.ReLU(),
            
            nn.Conv2d(64,128,3,1),
            nn.ReLU(),
            nn.Conv2d(128,128,3,1),
            nn.ReLU(),
            nn.Conv2d(128,128,3,2),
            
            nn.Conv2d(128,256,3,1),
            nn.ReLU(),
            nn.Conv2d(256,256,3,1),
            nn.ReLU(), 
            nn.Conv2d(256,256,3,2),
            
            nn.Conv2d(256,512,3,1),
            nn.ReLU(),
            nn.Conv2d(512,512,3,1),
            nn.ReLU(),
            nn.Conv2d(512,512,3,2),
            
            nn.Conv2d(512,512,3,1),
            nn.ReLU(),
            nn.Conv2d(512,512,3,1),
            nn.ReLU(),
            nn.Conv2d(512,512,3,2),
            
            nn.Conv2d(512,100,[2,3],1),
            nn.ReLU()
            
        )
        self.model2 = nn.Sequential(
            nn.Linear(160,160),
            nn.ReLU(),
            nn.Linear(160,50),
            nn.ReLU(),
            nn.Linear(50,self.output_size)
        )
    def forward(self, x, y):
        #x = np.ascontiguousarray(x, dtype=np.float32)
        x = np.reshape(x, [-1, 224,256,15])
        x = np.transpose(x, (0,3,1,2))
        x = Variable(torch.Tensor(x)).type(FloatTensor)
        y = Variable(torch.from_numpy(np.array(y))).type(FloatTensor)
        x = self.model1(x)
        x = x.view(x.size(0), 100)
        y = y.view(-1, 60)
        z = torch.cat((x,y),1)
        return self.model2(z)
    
   




if train:
    init_episode = 1
    max_episode = 10000
    replay_buffer = deque()
    state_buffer = deque()
    next_state_buffer = deque()
    output_buffer = deque()

    mainDQN = DQN(input_size, output_size)
    targetDQN = DQN(input_size, output_size)
    targetDQN.load_state_dict(mainDQN.state_dict())
    
    DISTANCE = []


    if retrain:
        mainDQN.load_state_dict(torch.load('checkpoints/mainDQN-1.pt'))
        targetDQN.load_state_dict(mainDQN.state_dict())

        print('model restroed!')

    if use_cuda:
        mainDQN.cuda()
        targetDQN.cuda()

    for episode in range(init_episode, max_episode):
        e = 1.0 / (episode/500 + 1)
        print ("episode:", episode, ", epsilon: ", e)
        done = False
        step_count = 0
        state = env.reset()
        score = 0
        distance = 0
        prev_output = -1
        repeat = 0

        while not done:
            if np.random.rand(1) < e or state is None or state.size == 1 or step_count <=10:
                output = random.randint(0, output_size -1)
                action,action_name = OutputToAction3(output)
                print("random: %15s" %(action_name), end=" ")

            else:
                predicted = mainDQN(acc_state, output_seq)
                output = int(predicted.max(1)[1].view(1,1))
                action,action_name = OutputToAction3(output)
                #print("output:",action_name, "predicted:", predicted)
                print("predicted: %15s" %(action_name), end=" ")

            for n in range(len(action)):
                next_state, reward, done, info = env.step(action[n])
                
                
                
                if done:
                    print('DONE!! final distance: ',info['distance'] )
                    break
            print("distance: %3d" %(info['distance']), end=" ")
            print('sys_reward: %2d' %(reward))
            state_buffer.append(next_state)
            output_buffer.append(action)

            prev_distance = distance
            distance = info['distance']
            got_distance = distance - prev_distance

            past_score = score
            score = info['score']
            got_score = score - past_score

            time = info['time']

            #reward = got_distance/2. #got_score/50 + got_distance/30
            reward = float(np.clip(reward, -2, 3)/10.)
            #print('my_reward: %2d' %(reward))
            if done:
                reward -= 1.0
                
                DISTANCE.append((episode, distance, e))
                with open('DISTANCE', 'wb') as fp:
                    pickle.dump(DISTANCE, fp)
                if distance>=3000:
                    reward = 1
                print("last reward: ", reward)

            if step_count>=10:
                acc_state = [state_buffer[-2-k] for k in range(5)]
                state_buffer.popleft()
                acc_state = np.reshape(acc_state, input_size[:3])
                acc_next_state = [state_buffer[-1-k] for k in range(5)]
                acc_next_state = np.reshape(acc_next_state, input_size[:3])

                output_seq = [output_buffer[-2-k] for k in range(5)]
                output_next_seq = [output_buffer[-1-k] for k in range(5)]
                output_buffer.popleft()

                replay_buffer.append((acc_state, output_seq, output_next_seq, output, reward, acc_next_state, done))

                if replay_buffer[-1][6]:
                    for k in range(1, 5):
                        replay_buffer[-1-k] = tuple(
                            replay_buffer[-1-k][0:4] + (-pow(0.9,k),) + replay_buffer[-1-k][5:]) # ??????
                if replay_buffer[-1][4] > 2.0 and replay_buffer[-1][6] == False:
                    for k in range(1, 5):
                        replay_buffer[-1-k] = tuple(
                            replay_buffer[-1-k][0:4] + (pow(0.9,k),) + replay_buffer[-1-k][5:])

                if len(replay_buffer) > REPLAY_MEMORY:
                    replay_buffer.popleft()
                acc_state = acc_next_state

            state = next_state
            step_count += 1
        if step_count > 100000:
            break

        if episode % 2 == 1:
            for _ in range(30):
                if len(replay_buffer) >= 10:
                    sample_idx = random.sample(range(0, len(replay_buffer)), 10)
                    minibatch = []
                    for i in sample_idx:
                        minibatch.append(replay_buffer[i])

                    l_rate = (1e-5 - 1e-4)*(1/max_episode)*episode + 1e-4
                    loss = ddqn_replay_train(mainDQN, targetDQN, minibatch, l_rate=l_rate)

                    print("Loss: %.3f,  l_rate: %.6f" %(loss, l_rate))

        if (episode+1) % 2 == 0:
            targetDQN.load_state_dict(mainDQN.state_dict())
            print('weights copied')

        if (episode+1) % 50 == 0:

            torch.save(mainDQN.state_dict(), 'checkpoints/mainDQN-1.pt')
            print('model saved')
        #env2 = wrappers.Monitor(env, 'gym-results', force=True)
        #for i in range(200):
        #    bot_play(mainDQN, env=env2)
        #env2.close()
       
            
        
else:
    mainDQN = DQN(input_size, output_size)
    targetDQN = DQN(input_size, output_size)
    for i in range(200):
        bot_play(mainDQN, env=env)
    env.close()
# Out:
# CUDA!!!!! True
# episode: 1 , epsilon:  0.998003992015968
# random:        Left+run distance:  39 sys_reward:  0
# random:           Right distance:  39 sys_reward:  1
# random:        Left+run distance:  39 sys_reward:  0
# random:            jump distance:  37 sys_reward: -1
# random:       Left+jump distance:  35 sys_reward: -1
# random:   Left+jump,run distance:  32 sys_reward: -1
# random:        Left+run distance:  27 sys_reward: -3
# random:  Right+jump,run distance:  23 sys_reward: -2
# random:           Right distance:  20 sys_reward: -1
# random:        Left+run distance:  17 sys_reward: -1
# random:            Down distance:  14 sys_reward: -1
# random:           Right distance:  14 sys_reward:  0
# random:              Up distance:  14 sys_reward:  0
# random:        jump,run distance:  14 sys_reward:  0
# random:            Left distance:  14 sys_reward:  0
# random:            jump distance:  14 sys_reward:  0
# random:        Left+run distance:  14 sys_reward:  0
# random:   Left+jump,run distance:  14 sys_reward:  0
# random:            Left distance:  14 sys_reward:  0
# random:      Right+jump distance:  14 sys_reward:  0
# random:  Right+jump,run distance:  15 sys_reward:  0
# random:            Left distance:  17 sys_reward:  1
# random:              Up distance:  17 sys_reward:  0
# random:        Left+run distance:  17 sys_reward:  0
# random:        Left+run distance:  16 sys_reward:  0
# random:       Left+jump distance:  14 sys_reward:  0
# random:        jump,run distance:  14 sys_reward:  0
# random:      Right+jump distance:  15 sys_reward:  1
# random:              Up distance:  15 sys_reward:  0
# predicted:      Right+jump distance:  15 sys_reward:  0
# random:              Up distance:  16 sys_reward:  0
# random:            Down distance:  17 sys_reward:  0
# random:           Right distance:  19 sys_reward:  1
# random:            Left distance:  20 sys_reward:  1
# random:       Right+run distance:  22 sys_reward:  1
# random:              Up distance:  22 sys_reward:  0
# random:  Right+jump,run distance:  23 sys_reward:  1
# random:            Left distance:  23 sys_reward:  0
# random:      Right+jump distance:  24 sys_reward:  1
# random:            Nope distance:  25 sys_reward:  1
# random:            jump distance:  26 sys_reward:  1
# random:        jump,run distance:  26 sys_reward:  0
# random:            Left distance:  26 sys_reward:  0
# random:   Left+jump,run distance:  24 sys_reward: -1
# random:            Left distance:  22 sys_reward: -1
# random:           Right distance:  19 sys_reward: -2
# random:        jump,run distance:  17 sys_reward: -1
# random:        jump,run distance:  15 sys_reward: -1
# random:            Nope distance:  14 sys_reward:  0
# random:      Right+jump distance:  15 sys_reward:  1
# random:       Right+run distance:  17 sys_reward:  1
# random:            Left distance:  20 sys_reward:  1
# random:        Left+run distance:  21 sys_reward:  0
# random:       Right+run distance:  21 sys_reward:  0
# random:            Nope distance:  23 sys_reward:  1
# random:           Right distance:  25 sys_reward:  2
# random:            jump distance:  28 sys_reward:  2
# random:      Right+jump distance:  32 sys_reward:  2
# random:            Left distance:  36 sys_reward:  2
# random:  Right+jump,run distance:  40 sys_reward:  2
# random:            Down distance:  45 sys_reward:  2
# random:        Left+run distance:  48 sys_reward:  1
# random:            Nope distance:  47 sys_reward:  0
# random:            Nope distance:  47 sys_reward:  0
# random:            Left distance:  46 sys_reward: -1
# random:            Left distance:  45 sys_reward: -1
# random:  Right+jump,run distance:  43 sys_reward: -1
# random:              Up distance:  42 sys_reward:  0
# random:       Right+run distance:  41 sys_reward:  0
# random:            Left distance:  40 sys_reward: -1
# random:            Left distance:  39 sys_reward: -1
# random:        jump,run distance:  37 sys_reward:  0
# random:            Nope distance:  37 sys_reward:  0
# random:            jump distance:  37 sys_reward:  0
# random:       Right+run distance:  38 sys_reward:  0
# random:      Right+jump distance:  41 sys_reward:  2
# random:       Right+run distance:  45 sys_reward:  2
# random:              Up distance:  51 sys_reward:  3
# random:           Right distance:  57 sys_reward:  3
# random:       Left+jump distance:  64 sys_reward:  3
# random:  Right+jump,run distance:  70 sys_reward:  3
# random:            jump distance:  77 sys_reward:  3
# random:      Right+jump distance:  84 sys_reward:  3
# random:        Left+run distance:  91 sys_reward:  3
# random:        jump,run distance:  97 sys_reward:  3
# random:            Left distance: 102 sys_reward:  2
# random:              Up distance: 107 sys_reward:  2
# random:       Left+jump distance: 112 sys_reward:  2
# random:       Left+jump distance: 116 sys_reward:  2
# random:            Nope distance: 115 sys_reward:  0
# random:            Down distance: 115 sys_reward:  0
# random:            Nope distance: 115 sys_reward:  0
# random:       Right+run distance: 116 sys_reward:  0
# random:       Left+jump distance: 117 sys_reward:  0
# random:  Right+jump,run distance: 118 sys_reward:  1
# random:            jump distance: 119 sys_reward:  0
# random:        jump,run distance: 121 sys_reward:  1
# random:            Down distance: 122 sys_reward:  0
# random:      Right+jump distance: 124 sys_reward:  1
# random:            jump distance: 127 sys_reward:  1
# random:            jump distance: 129 sys_reward:  1
# random:            jump distance: 132 sys_reward:  1
# random:        jump,run distance: 132 sys_reward:  0
# random:        jump,run distance: 132 sys_reward:  0
# random:           Right distance: 133 sys_reward:  1
# random:            jump distance: 134 sys_reward:  1
# random:            Down distance: 135 sys_reward:  1
# random:            Down distance: 136 sys_reward:  1
# random:   Left+jump,run distance: 136 sys_reward:  0
# random:            Left distance: 136 sys_reward:  0
# random:   Left+jump,run distance: 133 sys_reward: -2
# random:       Left+jump distance: 128 sys_reward: -3
# random:              Up distance: 123 sys_reward: -2
# random:            jump distance: 118 sys_reward: -3
# random:            Left distance: 113 sys_reward: -3
# random:       Right+run distance: 108 sys_reward: -2
# random:      Right+jump distance: 103 sys_reward: -2
# random:       Left+jump distance:  99 sys_reward: -2
# random:           Right distance:  95 sys_reward: -2
# random:      Right+jump distance:  92 sys_reward: -1
# random:      Right+jump distance:  91 sys_reward:  0
# random:        jump,run distance:  91 sys_reward:  0
# random:       Left+jump distance:  91 sys_reward:  0
# random:              Up distance:  90 sys_reward:  0
# random:      Right+jump distance:  89 sys_reward:  0
# random:       Left+jump distance:  89 sys_reward:  0
# random:        jump,run distance:  88 sys_reward: -1
# random:  Right+jump,run distance:  88 sys_reward:  0
# random:        jump,run distance:  89 sys_reward:  0
# random:        jump,run distance:  89 sys_reward:  0
# random:           Right distance:  89 sys_reward:  0
# random:       Left+jump distance:  90 sys_reward:  1
# random:        Left+run distance:  89 sys_reward: -1
# random:       Left+jump distance:  87 sys_reward: -1
# random:            jump distance:  83 sys_reward: -2
# random:            jump distance:  79 sys_reward: -2
# random:           Right distance:  77 sys_reward:  0
# random:            jump distance:  77 sys_reward:  0
# random:           Right distance:  79 sys_reward:  1
# random:            Nope distance:  80 sys_reward:  1
# random:           Right distance:  82 sys_reward:  1
# random:        Left+run distance:  85 sys_reward:  1
# random:           Right distance:  87 sys_reward:  1
# random:            Left distance:  87 sys_reward: -1
# random:        Left+run distance:  86 sys_reward: -1
# random:       Right+run distance:  85 sys_reward:  0
# random:            Nope distance:  86 sys_reward:  0
# random:            Left distance:  86 sys_reward:  0
# random:            jump distance:  84 sys_reward: -1
# random:            Nope distance:  82 sys_reward: -1
# random:  Right+jump,run distance:  81 sys_reward: -1
# random:            Left distance:  80 sys_reward: -1
# random:            Nope distance:  78 sys_reward: -1
# random:        Left+run distance:  76 sys_reward: -1
# random:            jump distance:  73 sys_reward: -1
# random:  Right+jump,run distance:  70 sys_reward: -1
# random:            Nope distance:  68 sys_reward: -1
# random:            Down distance:  65 sys_reward: -2
# random:   Left+jump,run distance:  63 sys_reward: -1
# random:            Left distance:  59 sys_reward: -2
# random:            jump distance:  55 sys_reward: -2
# random:        Left+run distance:  51 sys_reward: -2
# random:              Up distance:  47 sys_reward: -1
# random:        jump,run distance:  47 sys_reward:  0
# random:           Right distance:  47 sys_reward:  0
# random:           Right distance:  50 sys_reward:  2
# random:              Up distance:  53 sys_reward:  1
# random:            Down distance:  57 sys_reward:  2
# random:  Right+jump,run distance:  62 sys_reward:  3
# random:            Nope distance:  67 sys_reward:  2
# random:        Left+run distance:  72 sys_reward:  2
# random:       Right+run distance:  76 sys_reward:  2
# random:        Left+run distance:  81 sys_reward:  2
# random:            Nope distance:  84 sys_reward:  2
# random:       Right+run distance:  86 sys_reward:  1
# random:       Left+jump distance:  89 sys_reward:  1
# random:            Left distance:  92 sys_reward:  1
# random:        Left+run distance:  93 sys_reward:  0
# random:              Up distance:  94 sys_reward:  0
# random:       Left+jump distance:  94 sys_reward:  0
# random:   Left+jump,run distance:  93 sys_reward: -1
# random:              Up distance:  93 sys_reward:  0
# random:            Left distance:  92 sys_reward:  0
# random:            jump distance:  90 sys_reward: -1
# random:       Left+jump distance:  88 sys_reward: -1
# random:            Nope distance:  85 sys_reward: -2
# random:       Right+run distance:  83 sys_reward: -1
# random:            jump distance:  81 sys_reward: -1
# random:        jump,run distance:  79 sys_reward: -1
# random:  Right+jump,run distance:  78 sys_reward: -1
# random:            Down distance:  78 sys_reward:  0
# random:            Nope distance:  78 sys_reward:  0
# random:              Up distance:  78 sys_reward:  0
# random:      Right+jump distance:  79 sys_reward:  1
# random:      Right+jump distance:  80 sys_reward:  1
# random:  Right+jump,run distance:  83 sys_reward:  2
# random:  Right+jump,run distance:  86 sys_reward:  2
# random:      Right+jump distance:  90 sys_reward:  2
# random:              Up distance:  95 sys_reward:  2
# random:           Right distance: 101 sys_reward:  3
# random:        Left+run distance: 106 sys_reward:  2
# random:            jump distance: 111 sys_reward:  2
# random:   Left+jump,run distance: 116 sys_reward:  2
# random:      Right+jump distance: 120 sys_reward:  2
# random:            Left distance: 125 sys_reward:  2
# random:            Nope distance: 128 sys_reward:  1
# random:           Right distance: 130 sys_reward:  1
# random:            Nope distance: 132 sys_reward:  1
# random:       Left+jump distance: 134 sys_reward:  1
# random:            jump distance: 134 sys_reward:  0
# random:  Right+jump,run distance: 136 sys_reward:  1
# random:              Up distance: 137 sys_reward:  1
# random:            Down distance: 139 sys_reward:  1
# random:            Nope distance: 141 sys_reward:  1
# random:            jump distance: 143 sys_reward:  1
# random:            Left distance: 144 sys_reward:  1
# random:      Right+jump distance: 144 sys_reward:  0
# random:       Left+jump distance: 145 sys_reward:  0
# random:      Right+jump distance: 145 sys_reward:  1
# random:      Right+jump distance: 146 sys_reward:  1
# random:   Left+jump,run distance: 145 sys_reward: -1
# random:        Left+run distance: 144 sys_reward:  0
# random:            Down distance: 141 sys_reward: -1
# random:            jump distance: 139 sys_reward: -1
# random:              Up distance: 137 sys_reward: -1
# random:            Nope distance: 135 sys_reward: -1
# random:            jump distance: 133 sys_reward: -1
# random:        jump,run distance: 131 sys_reward: -1
# random:        jump,run distance: 129 sys_reward: -1
# random:        jump,run distance: 127 sys_reward: -1
# random:   Left+jump,run distance: 124 sys_reward: -1
# random:            Left distance: 121 sys_reward: -2
# random:           Right distance: 117 sys_reward: -2
# random:   Left+jump,run distance: 114 sys_reward: -2
# random:      Right+jump distance: 110 sys_reward: -2
# random:       Right+run distance: 108 sys_reward: -1
# random:            Left distance: 107 sys_reward: -1
# random:        Left+run distance: 105 sys_reward: -2
# random:       Right+run distance: 105 sys_reward:  0
# random:            Left distance: 105 sys_reward: -1
# random:       Left+jump distance: 103 sys_reward: -1
# random:        jump,run distance: 100 sys_reward: -2
# random:       Right+run distance:  98 sys_reward: -1
# random:            Down distance:  96 sys_reward: -1
# random:              Up distance:  94 sys_reward: -1
# random:            Nope distance:  93 sys_reward:  0
# random:  Right+jump,run distance:  91 sys_reward: -1
# random:        Left+run distance:  91 sys_reward: -1
# random:        jump,run distance:  89 sys_reward: -1
# random:            Nope distance:  88 sys_reward:  0
# random:              Up distance:  86 sys_reward: -1
# random:        Left+run distance:  84 sys_reward: -1
# random:        jump,run distance:  81 sys_reward: -1
# random:            jump distance:  78 sys_reward: -2
# random:        jump,run distance:  78 sys_reward:  0
# random:            Nope distance:  78 sys_reward:  0
# random:           Right distance:  78 sys_reward:  0
# random:       Right+run distance:  80 sys_reward:  1
# random:            Left distance:  80 sys_reward:  0
# random:           Right distance:  80 sys_reward:  0
# random:       Right+run distance:  82 sys_reward:  1
# random:        Left+run distance:  83 sys_reward: -1
# random:           Right distance:  83 sys_reward:  0
# random:            Nope distance:  84 sys_reward:  0
# random:   Left+jump,run distance:  85 sys_reward:  0
# random:            Down distance:  84 sys_reward:  0
# random:           Right distance:  84 sys_reward:  0
# random:        jump,run distance:  84 sys_reward:  0
# random:        Left+run distance:  85 sys_reward:  0
# random:        jump,run distance:  85 sys_reward:  0
# random:            Left distance:  84 sys_reward: -1
# random:            Left distance:  83 sys_reward: -1
# random:      Right+jump distance:  81 sys_reward: -1
# random:              Up distance:  80 sys_reward: -1
# random:      Right+jump distance:  80 sys_reward:  0
# random:      Right+jump distance:  80 sys_reward:  0
# random:            Down distance:  82 sys_reward:  1
# random:      Right+jump distance:  84 sys_reward:  1
# random:              Up distance:  86 sys_reward:  0
# random:        jump,run distance:  86 sys_reward:  0
# random:            Left distance:  85 sys_reward: -1
# random:   Left+jump,run distance:  83 sys_reward: -1
# random:            jump distance:  79 sys_reward: -2
# random:            Left distance:  75 sys_reward: -2
# random:  Right+jump,run distance:  70 sys_reward: -2
# random:        Left+run distance:  67 sys_reward: -1
# random:            Down distance:  67 sys_reward:  0
# random:  Right+jump,run distance:  68 sys_reward:  1
# random:            jump distance:  69 sys_reward:  0
# random:           Right distance:  72 sys_reward:  2
# random:      Right+jump distance:  76 sys_reward:  2
# random:            Down distance:  82 sys_reward:  3
# random:       Right+run distance:  89 sys_reward:  4
# random:            jump distance:  95 sys_reward:  3
# random:        Left+run distance: 101 sys_reward:  3
# random:           Right distance: 105 sys_reward:  2
# random:  Right+jump,run distance: 111 sys_reward:  3
# random:        jump,run distance: 117 sys_reward:  3
# random:        jump,run distance: 123 sys_reward:  3
# random:        Left+run distance: 129 sys_reward:  3
# random:        Left+run distance: 134 sys_reward:  2
# random:        Left+run distance: 138 sys_reward:  2
# random:  Right+jump,run distance: 142 sys_reward:  2
# random:              Up distance: 146 sys_reward:  2
# random:            Nope distance: 150 sys_reward:  2
# random:            Nope distance: 153 sys_reward:  1
# random:            jump distance: 156 sys_reward:  2
# random:       Left+jump distance: 158 sys_reward:  1
# random:           Right distance: 160 sys_reward:  1
# random:  Right+jump,run distance: 162 sys_reward:  1
# random:            Nope distance: 166 sys_reward:  2
# random:              Up distance: 169 sys_reward:  1
# random:  Right+jump,run distance: 170 sys_reward:  1
# random:              Up distance: 171 sys_reward:  1
# random:            Down distance: 172 sys_reward:  1
# random:        Left+run distance: 172 sys_reward:  0
# random:   Left+jump,run distance: 172 sys_reward:  0
# random:        Left+run distance: 169 sys_reward: -2
# random:            Down distance: 165 sys_reward: -2
# random:      Right+jump distance: 163 sys_reward: -1
# random:            Nope distance: 161 sys_reward: -1
# random:        jump,run distance: 159 sys_reward: -1
# random:           Right distance: 157 sys_reward: -1
# random:        jump,run distance: 156 sys_reward: -1
# random:           Right distance: 156 sys_reward:  0
# random:      Right+jump distance: 157 sys_reward:  1
# random:            Left distance: 158 sys_reward:  0
# random:            Nope distance: 159 sys_reward:  0
# random:            Left distance: 159 sys_reward:  0
# random:        Left+run distance: 158 sys_reward: -1
# random:        Left+run distance: 155 sys_reward: -2
# random:        Left+run distance: 150 sys_reward: -3
# random:        jump,run distance: 144 sys_reward: -3
# random:            jump distance: 137 sys_reward: -4
# random:        Left+run distance: 131 sys_reward: -3
# random:            Down distance: 124 sys_reward: -3
# random:        Left+run distance: 117 sys_reward: -3
# random:        jump,run distance: 110 sys_reward: -3
# random:   Left+jump,run distance: 103 sys_reward: -3
# random:            Down distance:  96 sys_reward: -3
# random:           Right distance:  92 sys_reward: -1
# random:      Right+jump distance:  92 sys_reward:  0
# random:            Down distance:  92 sys_reward:  0
# random:            Down distance:  92 sys_reward:  0
# random:        Left+run distance:  92 sys_reward:  0
# random:            Left distance:  92 sys_reward:  0
# random:           Right distance:  93 sys_reward:  1
# random:       Left+jump distance:  94 sys_reward:  1
# random:      Right+jump distance:  94 sys_reward:  0
# random:  Right+jump,run distance:  96 sys_reward:  1
# random:           Right distance:  99 sys_reward:  2
# random:           Right distance: 102 sys_reward:  2
# random:            Down distance: 107 sys_reward:  3
# random:              Up distance: 111 sys_reward:  2
# random:            jump distance: 115 sys_reward:  2
# random:        jump,run distance: 119 sys_reward:  2
# random:        jump,run distance: 119 sys_reward:  0
# random:           Right distance: 120 sys_reward:  1
# random:        Left+run distance: 119 sys_reward: -1
# random:        Left+run distance: 117 sys_reward: -2
# random:            Down distance: 115 sys_reward:  0
# random:       Right+run distance: 115 sys_reward:  0
# random:            Down distance: 116 sys_reward:  0
# random:            jump distance: 116 sys_reward:  0
# random:              Up distance: 116 sys_reward:  0
# random:  Right+jump,run distance: 116 sys_reward:  0
# random:       Right+run distance: 117 sys_reward:  1
# random:            jump distance: 119 sys_reward:  1
# random:  Right+jump,run distance: 122 sys_reward:  2
# random:              Up distance: 124 sys_reward:  1
# random:        jump,run distance: 124 sys_reward:  0
# random:              Up distance: 124 sys_reward:  0
# random:           Right distance: 125 sys_reward:  1
# random:  Right+jump,run distance: 126 sys_reward:  1
# random:            Nope distance: 128 sys_reward:  1
# random:              Up distance: 129 sys_reward:  0
# random:       Left+jump distance: 128 sys_reward: -1
# random:            Nope distance: 127 sys_reward:  0
# random:              Up distance: 125 sys_reward: -1
# random:            Left distance: 122 sys_reward: -2
# random:           Right distance: 120 sys_reward: -1
# random:   Left+jump,run distance: 120 sys_reward:  0
# random:            Down distance: 120 sys_reward:  0
# random:           Right distance: 120 sys_reward:  0
# random:      Right+jump distance: 120 sys_reward:  0
# random:        jump,run distance: 120 sys_reward:  0
# random:            Down distance: 120 sys_reward:  0
# random:      Right+jump distance: 120 sys_reward:  0
# random:        jump,run distance: 120 sys_reward:  0
# random:           Right distance: 120 sys_reward:  0
# random:            Left distance: 120 sys_reward:  0
# random:           Right distance: 120 sys_reward:  0
# random:        jump,run distance: 120 sys_reward:  0
# random:       Right+run distance: 120 sys_reward:  0
# random:            Down distance: 120 sys_reward:  0
# random:           Right distance: 120 sys_reward:  0
# random:           Right distance: 122 sys_reward:  1
# random:            Nope distance: 123 sys_reward:  0
# random:        Left+run distance: 123 sys_reward:  0
# random:   Left+jump,run distance: 121 sys_reward: -1
# random:        jump,run distance: 118 sys_reward: -1
# random:            Down distance: 115 sys_reward: -2
# random:        jump,run distance: 113 sys_reward: -1
# random:       Left+jump distance: 109 sys_reward: -2
# random:           Right distance: 106 sys_reward: -2
# random:            Left distance: 103 sys_reward: -2
# random:            Down distance: 100 sys_reward: -1
# random:        jump,run distance: 100 sys_reward:  0
# random:  Right+jump,run distance: 100 sys_reward:  0
# random:        Left+run distance: 101 sys_reward:  0
# random:       Right+run distance: 101 sys_reward:  0
# random:            Down distance: 103 sys_reward:  1
# random:        jump,run distance: 104 sys_reward:  1
# random:            Nope distance: 105 sys_reward:  1
# random:  Right+jump,run distance: 106 sys_reward:  1
# random:            Nope distance: 108 sys_reward:  1
# random:       Right+run distance: 111 sys_reward:  2
# random:       Right+run distance: 116 sys_reward:  3
# random:      Right+jump distance: 123 sys_reward:  4
# random:           Right distance: 130 sys_reward:  4
# random:      Right+jump distance: 137 sys_reward:  4
# random:            Nope distance: 144 sys_reward:  4
# random:       Right+run distance: 146 sys_reward:  0
# random:            Nope distance: 146 sys_reward:  0
# random:   Left+jump,run distance: 145 sys_reward: -1
# random:            Nope distance: 143 sys_reward: -1
# random:  Right+jump,run distance: 143 sys_reward:  0
# random:            jump distance: 143 sys_reward:  0
# random:            Left distance: 143 sys_reward:  0
# random:        Left+run distance: 142 sys_reward: -1
# random:       Right+run distance: 140 sys_reward: -1
# random:   Left+jump,run distance: 138 sys_reward: -1
# random:            Down distance: 136 sys_reward: -1
# random:      Right+jump distance: 137 sys_reward:  1
# random:       Right+run distance: 138 sys_reward:  1
# random:              Up distance: 140 sys_reward:  1
# random:      Right+jump distance: 142 sys_reward:  1
# random:      Right+jump distance: 146 sys_reward:  2
# random:            Left distance: 149 sys_reward:  1
# random:  Right+jump,run distance: 149 sys_reward:  0
# random:        Left+run distance: 149 sys_reward: -1
# random:           Right distance: 148 sys_reward: -1
# random:        Left+run distance: 147 sys_reward:  0
# random:           Right distance: 146 sys_reward:  0
# random:       Left+jump distance: 146 sys_reward:  0
# random:              Up distance: 145 sys_reward:  0
# random:            Left distance: 145 sys_reward:  0
# random:            jump distance: 144 sys_reward:  0
# random:       Right+run distance: 143 sys_reward: -1
# random:      Right+jump distance: 144 sys_reward:  1
# random:       Left+jump distance: 145 sys_reward:  0
# random:       Right+run distance: 145 sys_reward:  0
# random:            Left distance: 145 sys_reward: -1
# random:            Down distance: 145 sys_reward:  0
# random:            jump distance: 145 sys_reward:  0
# random:            Down distance: 145 sys_reward:  0
# random:            Nope distance: 145 sys_reward:  0
# random:            Nope distance: 145 sys_reward:  0
# random:            jump distance: 145 sys_reward:  0
# random:        Left+run distance: 144 sys_reward: -1
# random:            Left distance: 142 sys_reward: -2
# random:      Right+jump distance: 139 sys_reward: -1
# random:       Right+run distance: 137 sys_reward: -1
# random:            Down distance: 135 sys_reward: -1
# random:            Left distance: 134 sys_reward: -1
# random:       Left+jump distance: 131 sys_reward: -1
# random:           Right distance: 128 sys_reward: -1
# random:       Left+jump distance: 129 sys_reward:  0
# random:              Up distance: 128 sys_reward: -1
# random:       Right+run distance: 129 sys_reward:  1
# random:            jump distance: 130 sys_reward:  1
# random:            Nope distance: 131 sys_reward:  1
# random:           Right distance: 132 sys_reward:  1
# random:            Left distance: 132 sys_reward: -1
# random:       Left+jump distance: 131 sys_reward: -1
# random:        jump,run distance: 129 sys_reward: -1
# random:           Right distance: 127 sys_reward: -1
# random:            Down distance: 126 sys_reward: -1
# random:   Left+jump,run distance: 125 sys_reward: -1
# random:       Right+run distance: 123 sys_reward: -1
# random:            Down distance: 123 sys_reward:  0
# random:       Right+run distance: 123 sys_reward:  0
# random:            jump distance: 124 sys_reward:  0
# random:        Left+run distance: 126 sys_reward:  1
# random:   Left+jump,run distance: 126 sys_reward:  0
# random:        Left+run distance: 124 sys_reward: -1
# random:  Right+jump,run distance: 122 sys_reward: -1
# random:            Nope distance: 122 sys_reward:  0
# random:        jump,run distance: 122 sys_reward:  0
# random:        Left+run distance: 121 sys_reward: -1
# random:        jump,run distance: 120 sys_reward:  0
# random:        jump,run distance: 118 sys_reward: -1
# random:              Up distance: 116 sys_reward: -1
# random:        Left+run distance: 113 sys_reward: -2
# random:            Left distance: 109 sys_reward: -2
# random:        Left+run distance: 102 sys_reward: -4
# random:        jump,run distance:  95 sys_reward: -3
# random:            Left distance:  92 sys_reward:  0
# random:  Right+jump,run distance:  92 sys_reward:  0
# random:        Left+run distance:  93 sys_reward:  0
# random:            Nope distance:  93 sys_reward:  0
# random:       Right+run distance:  93 sys_reward:  0
# random:        jump,run distance:  95 sys_reward:  1
# random:   Left+jump,run distance:  96 sys_reward:  0
# random:        Left+run distance:  97 sys_reward:  0
# random:        jump,run distance:  96 sys_reward: -1
# random:            jump distance:  96 sys_reward:  0
# random:   Left+jump,run distance:  95 sys_reward: -1
# random:       Right+run distance:  94 sys_reward:  0
# random:        Left+run distance:  94 sys_reward:  0
# random:  Right+jump,run distance:  92 sys_reward: -1
# random:  Right+jump,run distance:  92 sys_reward:  0
# random:            Down distance:  92 sys_reward:  0
# random:            Down distance:  92 sys_reward:  0
# random:  Right+jump,run distance:  93 sys_reward:  1
# random:        Left+run distance:  94 sys_reward:  0
# random:       Right+run distance:  95 sys_reward:  1
# random:              Up distance:  96 sys_reward:  0
# random:           Right distance:  96 sys_reward:  0
# random:            Nope distance:  97 sys_reward:  0
# random:        Left+run distance:  97 sys_reward: -1
# random:              Up distance:  97 sys_reward:  0
# random:              Up distance:  97 sys_reward:  0
# random:        Left+run distance:  96 sys_reward: -1
# random:            jump distance:  94 sys_reward: -1
# random:  Right+jump,run distance:  93 sys_reward:  0
# random:            Left distance:  92 sys_reward:  0
# random:   Left+jump,run distance:  92 sys_reward:  0
# random:  Right+jump,run distance:  92 sys_reward:  0
# random:            Left distance:  93 sys_reward:  0
# random:            Down distance:  93 sys_reward:  0
# random:            Left distance:  93 sys_reward:  0
# random:   Left+jump,run distance:  92 sys_reward:  0
# random:  Right+jump,run distance:  93 sys_reward:  1
# random:       Left+jump distance:  94 sys_reward:  1
# random:  Right+jump,run distance:  94 sys_reward:  0
# random:      Right+jump distance:  96 sys_reward:  1
# random:      Right+jump distance: 100 sys_reward:  2
# random:   Left+jump,run distance: 104 sys_reward:  2
# random:        jump,run distance: 108 sys_reward:  2
# random:        Left+run distance: 110 sys_reward:  1
# random:   Left+jump,run distance: 111 sys_reward:  0
# random:           Right distance: 111 sys_reward:  1
# random:            Down distance: 111 sys_reward:  0
# random:           Right distance: 111 sys_reward:  0
# random:   Left+jump,run distance: 112 sys_reward:  0
# random:        jump,run distance: 112 sys_reward:  0
# random:        Left+run distance: 111 sys_reward: -1
# random:            Left distance: 109 sys_reward: -1
# random:   Left+jump,run distance: 104 sys_reward: -3
# random:      Right+jump distance:  99 sys_reward: -2
# random:           Right distance:  97 sys_reward:  0
# random:           Right distance:  98 sys_reward:  1
# random:            Left distance:  98 sys_reward:  0
# random:            Left distance:  97 sys_reward:  0
# random:        Left+run distance:  94 sys_reward: -2
# random:            Nope distance:  92 sys_reward:  0
# random:        Left+run distance:  92 sys_reward:  0
# random:  Right+jump,run distance:  92 sys_reward:  0
# random:            Down distance:  94 sys_reward:  1
# random:  Right+jump,run distance:  96 sys_reward:  1
# random:        Left+run distance:  99 sys_reward:  1
# random:            Nope distance: 101 sys_reward:  1
# random:  Right+jump,run distance: 104 sys_reward:  2
# random:            jump distance: 107 sys_reward:  1
# random:       Left+jump distance: 108 sys_reward:  0
# random:  Right+jump,run distance: 108 sys_reward:  1
# random:   Left+jump,run distance: 107 sys_reward: -1
# random:            jump distance: 106 sys_reward: -1
# random:      Right+jump distance: 106 sys_reward:  0
# random:            Nope distance: 107 sys_reward:  0
# random:       Left+jump distance: 108 sys_reward:  0
# random:            Left distance: 106 sys_reward: -1
# random:            Down distance: 103 sys_reward: -2
# random:       Left+jump distance: 100 sys_reward: -2
# random:      Right+jump distance:  96 sys_reward: -2
# random:        jump,run distance:  94 sys_reward:  0
# random:            Down distance:  94 sys_reward:  0
# random:           Right distance:  95 sys_reward:  0
# random:            Nope distance:  95 sys_reward:  0
# random:   Left+jump,run distance:  95 sys_reward:  0
# random:  Right+jump,run distance:  94 sys_reward:  0
# random:            Left distance:  94 sys_reward:  0
# random:       Right+run distance:  93 sys_reward:  0
# random:   Left+jump,run distance:  93 sys_reward:  0
# random:           Right distance:  93 sys_reward:  0
# random:           Right distance:  94 sys_reward:  0
# random:            Down distance:  95 sys_reward:  0
# random:       Right+run distance:  95 sys_reward:  0
# random:              Up distance:  96 sys_reward:  0
# random:   Left+jump,run distance:  95 sys_reward: -1
# random:              Up distance:  94 sys_reward:  0
# random:            jump distance:  92 sys_reward: -1
# random:       Right+run distance:  93 sys_reward:  1
# random:              Up distance:  94 sys_reward:  1
# random:       Right+run distance:  96 sys_reward:  1
# random:       Right+run distance:  99 sys_reward:  2
# random:        Left+run distance: 103 sys_reward:  2
# random:       Left+jump distance: 105 sys_reward:  1
# random:   Left+jump,run distance: 105 sys_reward:  0
# random:  Right+jump,run distance: 105 sys_reward:  0
# random:           Right distance: 106 sys_reward:  1
# random:        jump,run distance: 108 sys_reward:  1
# random:       Left+jump distance: 109 sys_reward:  0
# random:        Left+run distance: 109 sys_reward:  0
# random:            Nope distance: 108 sys_reward: -1
# random:  Right+jump,run distance: 108 sys_reward:  0
# random:            jump distance: 108 sys_reward:  0
# random:            Nope distance: 108 sys_reward:  0
# random:  Right+jump,run distance: 109 sys_reward:  0
# random:              Up distance: 112 sys_reward:  2
# random:            Down distance: 114 sys_reward:  1
# random:            Nope distance: 116 sys_reward:  1
# random:            jump distance: 117 sys_reward:  0
# random:  Right+jump,run distance: 119 sys_reward:  1
# random:      Right+jump distance: 123 sys_reward:  2
# random:            Down distance: 128 sys_reward:  2
# random:       Left+jump distance: 133 sys_reward:  2
# random:            jump distance: 136 sys_reward:  1
# random:  Right+jump,run distance: 140 sys_reward:  2
# random:  Right+jump,run distance: 146 sys_reward:  3
# random:       Right+run distance: 154 sys_reward:  4
# random:              Up distance: 163 sys_reward:  4
# random:            Nope distance: 170 sys_reward:  3
# random:       Right+run distance: 177 sys_reward:  3
# random:       Right+run distance: 186 sys_reward:  4
# random:   Left+jump,run distance: 195 sys_reward:  4
# random:      Right+jump distance: 204 sys_reward:  5
# random:      Right+jump distance: 215 sys_reward:  6
# random:           Right distance: 223 sys_reward:  4
# random:              Up distance: 229 sys_reward:  3
# random:            Left distance: 235 sys_reward:  3
# random:            Down distance: 238 sys_reward:  1
# random:   Left+jump,run distance: 238 sys_reward:  0
# random:   Left+jump,run distance: 238 sys_reward:  1
# random:            jump distance: 238 sys_reward:  0
# random:        jump,run distance: 238 sys_reward:  0
# random:        jump,run distance: 238 sys_reward:  0
# random:        jump,run distance: 238 sys_reward:  0
# random:       Right+run distance: 239 sys_reward:  0
# random:       Left+jump distance: 240 sys_reward:  0
# random:       Left+jump distance: 239 sys_reward: -1
# random:       Right+run distance: 239 sys_reward:  0
# random:        jump,run distance: 238 sys_reward:  0
# random:        jump,run distance: 238 sys_reward:  0
# random:            Left distance: 238 sys_reward:  0
# random:              Up distance: 238 sys_reward:  0
# random:            Down distance: 238 sys_reward:  0
# random:        jump,run distance: 238 sys_reward:  0
# random:        Left+run distance: 238 sys_reward:  0
# random:       Left+jump distance: 238 sys_reward:  0
# random:       Left+jump distance: 238 sys_reward:  0
# random:            Left distance: 237 sys_reward: -1
# random:       Left+jump distance: 236 sys_reward: -1
# random:      Right+jump distance: 235 sys_reward:  0
# random:      Right+jump distance: 237 sys_reward:  1
# random:       Right+run distance: 239 sys_reward:  1
# random:        jump,run distance: 243 sys_reward:  2
# random:       Left+jump distance: 246 sys_reward:  1
# random:  Right+jump,run distance: 250 sys_reward:  2
# random:            Nope distance: 253 sys_reward:  2
# random:   Left+jump,run distance: 257 sys_reward:  2
# random:        jump,run distance: 259 sys_reward:  1
# random:      Right+jump distance: 263 sys_reward:  2
# random:        jump,run distance: 266 sys_reward:  2
# random:              Up distance: 266 sys_reward:  0
# random:            jump distance: 266 sys_reward:  0
# random:       Right+run distance: 266 sys_reward:  0
# random:            jump distance: 267 sys_reward:  0
# random:      Right+jump distance: 269 sys_reward:  1
# random:  Right+jump,run distance: 271 sys_reward:  1
# random:            Left distance: 272 sys_reward:  0
# random:   Left+jump,run distance: 271 sys_reward: -1
# random:       Left+jump distance: 269 sys_reward: -1
# random:            jump distance: 266 sys_reward: -2
# random:            jump distance: 264 sys_reward: -1
# random:   Left+jump,run distance: 260 sys_reward: -2
# random:            Nope distance: 257 sys_reward: -2
# random:              Up distance: 253 sys_reward: -2
# random:       Left+jump distance: 249 sys_reward: -2
# random:            Nope distance: 244 sys_reward: -2
# random:              Up distance: 239 sys_reward: -3
# random:       Left+jump distance: 234 sys_reward: -3
# random:           Right distance: 229 sys_reward: -2
# random:            Nope distance: 226 sys_reward: -1
# random:           Right distance: 226 sys_reward:  1
# random:           Right distance: 227 sys_reward:  1
# random:            Nope distance: 229 sys_reward:  1
# random:            Left distance: 229 sys_reward: -1
# random:      Right+jump distance: 229 sys_reward:  0
# random:   Left+jump,run distance: 228 sys_reward: -1
# random:  Right+jump,run distance: 228 sys_reward:  0
# random:            jump distance: 228 sys_reward:  0
# random:       Right+run distance: 228 sys_reward:  0
# random:           Right distance: 230 sys_reward:  1
# random:           Right distance: 234 sys_reward:  2
# random:   Left+jump,run distance: 239 sys_reward:  3
# random:           Right distance: 243 sys_reward:  2
# random:              Up distance: 248 sys_reward:  2
# random:       Right+run distance: 253 sys_reward:  2
# random:        Left+run distance: 259 sys_reward:  3
# random:           Right distance: 264 sys_reward:  2
# random:              Up distance: 270 sys_reward:  3
# random:      Right+jump distance: 275 sys_reward:  2
# random:           Right distance: 282 sys_reward:  4
# random:            Left distance: 288 sys_reward:  3
# random:       Right+run distance: 295 sys_reward:  4
# random:        Left+run distance: 301 sys_reward:  3
# random:   Left+jump,run distance: 307 sys_reward:  3
# random:  Right+jump,run distance: 312 sys_reward:  3
# random:            Down distance: 319 sys_reward:  3
# random:        jump,run distance: 322 sys_reward:  0
# random:      Right+jump distance: 322 sys_reward:  0
# random:            Down distance: 322 sys_reward:  0
# random:              Up distance: 322 sys_reward:  0
# random:            Left distance: 321 sys_reward: -1
# random:              Up distance: 321 sys_reward:  0
# random:              Up distance: 321 sys_reward:  0
# random:       Right+run distance: 321 sys_reward:  0
# random:            jump distance: 322 sys_reward:  0
# random:  Right+jump,run distance: 322 sys_reward:  0
# random:        jump,run distance: 322 sys_reward:  0
# random:            Down distance: 322 sys_reward:  0
# random:       Left+jump distance: 321 sys_reward: -1
# random:        jump,run distance: 319 sys_reward: -1
# random:  Right+jump,run distance: 318 sys_reward: -1
# random:  Right+jump,run distance: 319 sys_reward:  0
# random:            Nope distance: 320 sys_reward:  0
# random:   Left+jump,run distance: 320 sys_reward:  0
# random:      Right+jump distance: 320 sys_reward:  0
# random:   Left+jump,run distance: 321 sys_reward:  0
# random:       Right+run distance: 321 sys_reward:  0
# random:        jump,run distance: 322 sys_reward:  1
# random:              Up distance: 322 sys_reward:  0
# random:            Down distance: 322 sys_reward:  0
# random:           Right distance: 322 sys_reward:  0
# random:            Down distance: 322 sys_reward:  0
# random:      Right+jump distance: 322 sys_reward:  0
# random:  Right+jump,run distance: 322 sys_reward:  0
# random:        Left+run distance: 322 sys_reward:  0
# random:            Down distance: 320 sys_reward: -1
# random:        jump,run distance: 319 sys_reward: -1
# random:       Right+run distance: 319 sys_reward:  0
# random:            Nope distance: 319 sys_reward:  0
# random:       Right+run distance: 320 sys_reward:  1
# random:            Down distance: 320 sys_reward:  0
# random:      Right+jump distance: 320 sys_reward:  0
# random:              Up distance: 321 sys_reward:  0
# random:        jump,run distance: 322 sys_reward:  0
# random:  Right+jump,run distance: 322 sys_reward:  0
# random:              Up distance: 322 sys_reward:  0
# random:            jump distance: 322 sys_reward:  0
# random:            jump distance: 322 sys_reward:  0
# random:       Left+jump distance: 321 sys_reward: -1
# random:  Right+jump,run distance: 321 sys_reward:  0
# random:       Right+run distance: 322 sys_reward:  0
# random:        jump,run distance: 322 sys_reward:  0
# random:       Left+jump distance: 321 sys_reward:  0
# random:           Right distance: 320 sys_reward:  0
# random:       Right+run distance: 321 sys_reward:  1
# random:           Right distance: 322 sys_reward:  1
# random:  Right+jump,run distance: 322 sys_reward:  0
# random:      Right+jump distance: 322 sys_reward:  0
# random:            Nope distance: 322 sys_reward:  0
# random:  Right+jump,run distance: 322 sys_reward:  0
# random:        jump,run distance: 322 sys_reward:  0
# random:        jump,run distance: 322 sys_reward:  0
# random:        Left+run distance: 321 sys_reward: -1
# random:       Left+jump distance: 319 sys_reward: -1
# random:            Down distance: 315 sys_reward: -2
# random:        Left+run distance: 310 sys_reward: -3
# random:           Right distance: 305 sys_reward: -2
# random:        jump,run distance: 301 sys_reward: -2
# random:        Left+run distance: 296 sys_reward: -2
# random:        Left+run distance: 289 sys_reward: -3
# random:        Left+run distance: 282 sys_reward: -3
# random:           Right distance: 276 sys_reward: -2
# random:            jump distance: 271 sys_reward: -2
# random:   Left+jump,run distance: 265 sys_reward: -3
# random:       Left+jump distance: 257 sys_reward: -4
# random:            jump distance: 248 sys_reward: -4
# random:            jump distance: 239 sys_reward: -4
# random:      Right+jump distance: 233 sys_reward: -2
# random:            Left distance: 233 sys_reward:  0
# random:        Left+run distance: 233 sys_reward:  0
# random:      Right+jump distance: 233 sys_reward:  0
# random:  Right+jump,run distance: 236 sys_reward:  2
# random:        jump,run distance: 239 sys_reward:  1
# random:        jump,run distance: 243 sys_reward:  2
# random:      Right+jump distance: 248 sys_reward:  3
# random:        Left+run distance: 253 sys_reward:  3
# random:       Right+run distance: 257 sys_reward:  2
# random:           Right distance: 264 sys_reward:  4
# random:            Nope distance: 271 sys_reward:  4
# random:       Right+run distance: 279 sys_reward:  5
# random:            jump distance: 288 sys_reward:  5
# random:            jump distance: 297 sys_reward:  4
# random:            Left distance: 306 sys_reward:  4
# random:  Right+jump,run distance: 314 sys_reward:  4
# random:        Left+run distance: 322 sys_reward:  4
# random:            Nope distance: 330 sys_reward:  4
# random:      Right+jump distance: 337 sys_reward:  4
# random:            jump distance: 344 sys_reward:  4
# random:              Up distance: 351 sys_reward:  4
# random:           Right distance: 358 sys_reward:  4
# random:           Right distance: 365 sys_reward:  4
# random:      Right+jump distance: 372 sys_reward:  4
# random:           Right distance: 379 sys_reward:  4
# random:        Left+run distance: 385 sys_reward:  3
# random:            Left distance: 390 sys_reward:  2
# random:            jump distance: 393 sys_reward:  2
# random:            jump distance: 396 sys_reward:  1
# random:  Right+jump,run distance: 400 sys_reward:  2
# random:            jump distance: 405 sys_reward:  2
# random:              Up distance: 411 sys_reward:  3
# random:   Left+jump,run distance: 415 sys_reward:  2
# random:            Left distance: 418 sys_reward:  1
# random:            Down distance: 419 sys_reward:  1
# random:        Left+run distance: 419 sys_reward:  0
# random:   Left+jump,run distance: 419 sys_reward:  0
# random:            Left distance: 417 sys_reward: -1
# random:       Right+run distance: 415 sys_reward:  0
# random:       Left+jump distance: 414 sys_reward:  0
# random:       Right+run distance: 414 sys_reward:  0
# random:        jump,run distance: 416 sys_reward:  1
# random:       Right+run distance: 418 sys_reward:  2
# random:        jump,run distance: 418 sys_reward:  0
# random:            Nope distance: 418 sys_reward:  0
# random:        jump,run distance: 418 sys_reward:  0
# random:              Up distance: 418 sys_reward:  0
# random:   Left+jump,run distance: 418 sys_reward:  0
# random:       Right+run distance: 417 sys_reward:  0
# random:       Right+run distance: 417 sys_reward:  0
# random:              Up distance: 418 sys_reward:  0
# random:      Right+jump distance: 418 sys_reward:  0
# random:            Down distance: 418 sys_reward:  0
# random:        jump,run distance: 418 sys_reward:  0
# random:            jump distance: 418 sys_reward:  0
# random:      Right+jump distance: 418 sys_reward:  0
# random:       Left+jump distance: 417 sys_reward: -1
# random:   Left+jump,run distance: 415 sys_reward: -2
# random:  Right+jump,run distance: 415 sys_reward:  0
# random:            Left distance: 415 sys_reward:  0
# random:            jump distance: 414 sys_reward:  0
# random:            Nope distance: 414 sys_reward:  0
# random:       Left+jump distance: 414 sys_reward:  0
# random:            Left distance: 414 sys_reward:  0
# random:           Right distance: 414 sys_reward:  0
# random:        jump,run distance: 414 sys_reward:  0
# random:           Right distance: 414 sys_reward:  0
# random:   Left+jump,run distance: 415 sys_reward:  0
# random:       Left+jump distance: 414 sys_reward: -1
# random:       Left+jump distance: 414 sys_reward:  0
# random:        jump,run distance: 414 sys_reward:  0
# random:        Left+run distance: 414 sys_reward:  0
# random:  Right+jump,run distance: 414 sys_reward:  1
# random:  Right+jump,run distance: 415 sys_reward:  1
# random:  Right+jump,run distance: 417 sys_reward:  1
# random:        Left+run distance: 418 sys_reward:  0
# random:       Right+run distance: 418 sys_reward:  1
# random:            Down distance: 418 sys_reward:  0
# random:            Left distance: 418 sys_reward:  0
# random:       Left+jump distance: 415 sys_reward: -2
# random:           Right distance: 414 sys_reward:  0
# random:            Nope distance: 414 sys_reward:  0
# random:            Nope distance: 415 sys_reward:  1
# random:  Right+jump,run distance: 416 sys_reward:  1
# random:              Up distance: 417 sys_reward:  0
# random:              Up distance: 417 sys_reward:  0
# random:  Right+jump,run distance: 417 sys_reward:  0
# random:        Left+run distance: 418 sys_reward:  0
# random:  Right+jump,run distance: 418 sys_reward:  0
# random:              Up distance: 418 sys_reward:  0
# random:  Right+jump,run distance: 418 sys_reward:  0
# random:            Nope distance: 418 sys_reward:  0
# random:            Nope distance: 418 sys_reward:  0
# random:           Right distance: 418 sys_reward:  0
# random:        jump,run distance: 418 sys_reward:  0
# random:            Nope distance: 418 sys_reward:  0
# random:            Nope distance: 418 sys_reward:  0
# random:            Left distance: 417 sys_reward: -1
# random:       Left+jump distance: 415 sys_reward: -1
# random:              Up distance: 414 sys_reward:  0
# random:            jump distance: 414 sys_reward:  0
# random:           Right distance: 414 sys_reward:  0
# random:        jump,run distance: 415 sys_reward:  0
# random:      Right+jump distance: 417 sys_reward:  1
# random:            Nope distance: 418 sys_reward:  0
# random:        Left+run distance: 417 sys_reward:  0
# random:       Right+run distance: 417 sys_reward:  1
# random:            jump distance: 418 sys_reward:  1
# random:      Right+jump distance: 418 sys_reward:  0
# random:       Left+jump distance: 418 sys_reward:  0
# random:  Right+jump,run distance: 418 sys_reward:  0
# random:           Right distance: 420 sys_reward:  1
# random:       Right+run distance: 422 sys_reward:  1
# random:       Left+jump distance: 423 sys_reward: -1
# random:        Left+run distance: 422 sys_reward: -1
# random:            Down distance: 421 sys_reward:  0
# random:            Down distance: 421 sys_reward:  0
# random:   Left+jump,run distance: 421 sys_reward:  0
# random:       Left+jump distance: 420 sys_reward:  0
# random:            Nope distance: 418 sys_reward: -1
# random:  Right+jump,run distance: 416 sys_reward: -1
# ...
# random:        Left+run distance: 319 sys_reward:  0
# random:           Right distance: 319 sys_reward:  1
# random:            Left distance: 318 sys_reward: -1
# random:            Left distance: 318 sys_reward:  0
# random:            Nope distance: 318 sys_reward:  0
# random:   Left+jump,run distance: 318 sys_reward:  0
# random:              Up distance: 318 sys_reward:  0
# random:        jump,run distance: 318 sys_reward:  0
# random:      Right+jump distance: 319 sys_reward:  1
# random:              Up distance: 321 sys_reward:  1
# random:   Left+jump,run distance: 321 sys_reward:  0
# random:        jump,run distance: 321 sys_reward:  0
# random:       Right+run distance: 321 sys_reward:  0
# random:        Left+run distance: 321 sys_reward:  0
# random:        jump,run distance: 319 sys_reward: -1
# random:        Left+run distance: 317 sys_reward: -1
# random:           Right distance: 315 sys_reward: -1
# random:       Right+run distance: 314 sys_reward:  0
# random:   Left+jump,run distance: 315 sys_reward:  1
# random:       Left+jump distance: 314 sys_reward: -1
# random:   Left+jump,run distance: 312 sys_reward: -1
# random:            Down distance: 308 sys_reward: -2
# random:            jump distance: 305 sys_reward: -1
# random:            Left distance: 305 sys_reward:  0
# random:        Left+run distance: 305 sys_reward:  0
# random:       Right+run distance: 306 sys_reward:  1
# random:        jump,run distance: 307 sys_reward:  1
# random:            Left distance: 308 sys_reward:  0
# random:   Left+jump,run distance: 308 sys_reward:  0
# random:   Left+jump,run distance: 307 sys_reward: -1
# random:       Left+jump distance: 305 sys_reward:  0
# random:           Right distance: 306 sys_reward:  1
# random:   Left+jump,run distance: 306 sys_reward:  0
# random:              Up distance: 307 sys_reward:  0
# random:        jump,run distance: 307 sys_reward:  0
# random:        Left+run distance: 307 sys_reward:  0
# random:       Left+jump distance: 305 sys_reward: -1
# random:            Left distance: 305 sys_reward:  0
# random:            jump distance: 305 sys_reward:  0
# random:              Up distance: 305 sys_reward:  0
# random:        jump,run distance: 305 sys_reward:  0
# random:      Right+jump distance: 305 sys_reward:  0
# random:            Nope distance: 307 sys_reward:  1
# random:   Left+jump,run distance: 307 sys_reward: -1
# random:           Right distance: 308 sys_reward:  1
# random:            Left distance: 307 sys_reward: -1
# random:   Left+jump,run distance: 305 sys_reward: -1
# random:            Nope distance: 305 sys_reward:  0
# random:           Right distance: 306 sys_reward:  1
# random:        jump,run distance: 307 sys_reward:  0
# random:   Left+jump,run distance: 308 sys_reward:  0
# random:   Left+jump,run distance: 308 sys_reward:  0
# random:        Left+run distance: 305 sys_reward: -2
# random:           Right distance: 306 sys_reward:  1
# random:           Right distance: 308 sys_reward:  1
# random:            Nope distance: 311 sys_reward:  2
# random:  Right+jump,run distance: 313 sys_reward:  1
# random:              Up distance: 317 sys_reward:  2
# random:            Left distance: 319 sys_reward:  1
# random:  Right+jump,run distance: 322 sys_reward:  1
# random:            Nope distance: 325 sys_reward:  1
# random:       Right+run distance: 329 sys_reward:  2
# random:   Left+jump,run distance: 333 sys_reward:  2
# predicted:  Right+jump,run distance: 337 sys_reward:  2
# random:        Left+run distance: 341 sys_reward:  2
# random:   Left+jump,run distance: 344 sys_reward:  2
# random:       Left+jump distance: 346 sys_reward:  1
# random:  Right+jump,run distance: 348 sys_reward:  1
# random:            Down distance: 350 sys_reward:  1
# random:            Down distance: 353 sys_reward:  1
# random:           Right distance: 354 sys_reward:  0
# random:            Left distance: 354 sys_reward:  0
# random:       Right+run distance: 354 sys_reward:  0
# random:           Right distance: 354 sys_reward:  0
# random:            Left distance: 354 sys_reward:  0
# random:        Left+run distance: 351 sys_reward: -2
# random:            jump distance: 350 sys_reward:  0
# random:        Left+run distance: 350 sys_reward:  0
# random:       Left+jump distance: 350 sys_reward:  0
# random:            Left distance: 350 sys_reward:  0
# random:      Right+jump distance: 351 sys_reward:  1
# random:           Right distance: 353 sys_reward:  1
# random:   Left+jump,run distance: 354 sys_reward:  0
# random:            Left distance: 352 sys_reward: -1
# random:            Down distance: 350 sys_reward:  0
# random:              Up distance: 350 sys_reward:  0
# random:        Left+run distance: 350 sys_reward:  0
# random:  Right+jump,run distance: 351 sys_reward:  1
# random:              Up distance: 352 sys_reward:  0
# random:            Down distance: 352 sys_reward:  0
# random:      Right+jump distance: 352 sys_reward:  0
# random:      Right+jump distance: 353 sys_reward:  0
# random:            Down distance: 354 sys_reward:  0
# random:           Right distance: 354 sys_reward:  0
# random:            Down distance: 354 sys_reward:  0
# random:        jump,run distance: 354 sys_reward:  0
# random:       Right+run distance: 354 sys_reward:  0
# random:              Up distance: 354 sys_reward:  0
# random:            Nope distance: 354 sys_reward:  0
# random:        jump,run distance: 354 sys_reward:  0
# random:        Left+run distance: 354 sys_reward:  0
# predicted:  Right+jump,run distance: 353 sys_reward:  0
# random:              Up distance: 353 sys_reward:  0
# random:      Right+jump distance: 354 sys_reward:  1
# random:  Right+jump,run distance: 354 sys_reward:  0
# random:      Right+jump distance: 354 sys_reward:  0
# random:   Left+jump,run distance: 353 sys_reward: -1
# random:   Left+jump,run distance: 351 sys_reward: -1
# random:            Down distance: 350 sys_reward:  0
# random:        jump,run distance: 350 sys_reward:  0
# random:            jump distance: 350 sys_reward:  0
# random:            jump distance: 350 sys_reward:  0
# random:        Left+run distance: 350 sys_reward:  0
# random:            Down distance: 349 sys_reward:  0
# random:        Left+run distance: 347 sys_reward: -1
# random:       Left+jump distance: 344 sys_reward: -2
# random:      Right+jump distance: 340 sys_reward: -2
# random:            jump distance: 338 sys_reward: -1
# random:       Left+jump distance: 335 sys_reward: -1
# random:        jump,run distance: 331 sys_reward: -2
# random:  Right+jump,run distance: 327 sys_reward: -2
# random:       Right+run distance: 325 sys_reward: -1
# random:              Up distance: 323 sys_reward: -1
# random:            Left distance: 321 sys_reward: -1
# random:      Right+jump distance: 319 sys_reward: -1
# random:            jump distance: 317 sys_reward: -1
# random:  Right+jump,run distance: 316 sys_reward:  0
# random:  Right+jump,run distance: 318 sys_reward:  1
# random:            jump distance: 320 sys_reward:  1
# random:            Nope distance: 322 sys_reward:  1
# random:              Up distance: 322 sys_reward:  0
# random:              Up distance: 322 sys_reward:  0
# random:  Right+jump,run distance: 322 sys_reward:  0
# random:        jump,run distance: 322 sys_reward:  0
# random:        Left+run distance: 321 sys_reward: -1
# random:   Left+jump,run distance: 319 sys_reward: -1
# random:  Right+jump,run distance: 316 sys_reward: -1
# random:            Down distance: 315 sys_reward:  0
# random:            Down distance: 315 sys_reward:  0
# random:        jump,run distance: 315 sys_reward:  0
# random:            jump distance: 315 sys_reward:  0
# random:        jump,run distance: 315 sys_reward:  0
# random:            jump distance: 315 sys_reward:  0
# random:        Left+run distance: 315 sys_reward:  0
# random:            jump distance: 313 sys_reward: -1
# random:        jump,run distance: 311 sys_reward: -1
# random:       Left+jump distance: 309 sys_reward: -1
# random:            Nope distance: 305 sys_reward: -2
# random:        Left+run distance: 305 sys_reward:  0
# random:        Left+run distance: 305 sys_reward:  0
# random:       Left+jump distance: 305 sys_reward:  0
# random:              Up distance: 305 sys_reward:  0
# random:   Left+jump,run distance: 305 sys_reward:  0
# random:   Left+jump,run distance: 305 sys_reward:  0
# random:       Left+jump distance: 305 sys_reward:  0
# random:              Up distance: 305 sys_reward:  0
# random:            Left distance: 305 sys_reward:  0
# random:      Right+jump distance: 305 sys_reward:  0
# random:            Down distance: 307 sys_reward:  1
# random:  Right+jump,run distance: 309 sys_reward:  1
# random:      Right+jump distance: 314 sys_reward:  3
# random:  Right+jump,run distance: 320 sys_reward:  3
# random:           Right distance: 322 sys_reward: -1
# random:      Right+jump distance: 322 sys_reward:  0
# random:        Left+run distance: 321 sys_reward: -1
# random:              Up distance: 320 sys_reward:  0
# random:        Left+run distance: 320 sys_reward:  0
# random:            Left distance: 318 sys_reward: -1
# random:        jump,run distance: 318 sys_reward:  0
# random:            Left distance: 318 sys_reward:  0
# random:        Left+run distance: 317 sys_reward: -1
# random:      Right+jump distance: 316 sys_reward:  0
# random:       Left+jump distance: 316 sys_reward:  0
# random:  Right+jump,run distance: 316 sys_reward:  0
# random:            Down distance: 316 sys_reward:  0
# random:  Right+jump,run distance: 317 sys_reward:  1
# random:            Left distance: 317 sys_reward:  0
# random:        Left+run distance: 317 sys_reward:  0
# random:        jump,run distance: 315 sys_reward: -1
# random:       Left+jump distance: 313 sys_reward: -1
# random:            Left distance: 308 sys_reward: -3
# random:        Left+run distance: 305 sys_reward:  0
# random:            Nope distance: 305 sys_reward:  0
# random:       Left+jump distance: 305 sys_reward:  0
# random:            Left distance: 305 sys_reward:  0
# random:       Left+jump distance: 305 sys_reward:  0
# random:       Left+jump distance: 305 sys_reward:  0
# random:       Right+run distance: 306 sys_reward:  1
# random:            Down distance: 306 sys_reward:  0
# random:       Right+run distance: 307 sys_reward:  0
# random:            jump distance: 308 sys_reward:  0
# random:      Right+jump distance: 310 sys_reward:  1
# random:            jump distance: 313 sys_reward:  1
# random:   Left+jump,run distance: 315 sys_reward:  1
# random:  Right+jump,run distance: 317 sys_reward:  1
# random:  Right+jump,run distance: 320 sys_reward:  2
# random:            Left distance: 323 sys_reward:  2
# random:           Right distance: 326 sys_reward:  2
# random:            Left distance: 329 sys_reward:  2
# random:            Nope distance: 331 sys_reward:  1
# random:   Left+jump,run distance: 333 sys_reward:  1
# random:  Right+jump,run distance: 335 sys_reward:  1
# random:        jump,run distance: 337 sys_reward:  1
# random:            jump distance: 339 sys_reward:  1
# random:              Up distance: 342 sys_reward:  2
# random:       Right+run distance: 344 sys_reward:  1
# random:        jump,run distance: 347 sys_reward:  1
# random:           Right distance: 351 sys_reward:  2
# random:   Left+jump,run distance: 354 sys_reward:  1
# random:            jump distance: 354 sys_reward:  0
# predicted:  Right+jump,run distance: 354 sys_reward:  0
# random:       Left+jump distance: 354 sys_reward:  0
# random:       Right+run distance: 354 sys_reward:  0
# random:  Right+jump,run distance: 354 sys_reward:  0
# random:        Left+run distance: 354 sys_reward:  0
# random:      Right+jump distance: 354 sys_reward:  0
# random:        Left+run distance: 354 sys_reward:  0
# random:      Right+jump distance: 354 sys_reward:  0
# random:        jump,run distance: 354 sys_reward:  0
# random:           Right distance: 354 sys_reward:  0
# random:            Nope distance: 354 sys_reward:  0
# random:  Right+jump,run distance: 354 sys_reward:  0
# random:           Right distance: 354 sys_reward:  0
# random:      Right+jump distance: 354 sys_reward:  0
# random:            Nope distance: 354 sys_reward:  0
# random:       Right+run distance: 354 sys_reward:  0
# random:            Left distance: 353 sys_reward: -1
# random:            Left distance: 352 sys_reward: -1
# random:            Down distance: 352 sys_reward:  0
# random:       Right+run distance: 352 sys_reward:  0
# random:            Down distance: 353 sys_reward:  0
# random:  Right+jump,run distance: 353 sys_reward:  0
# random:      Right+jump distance: 354 sys_reward:  0
# random:        Left+run distance: 353 sys_reward: -1
# random:       Left+jump distance: 351 sys_reward: -1
# random:      Right+jump distance: 350 sys_reward:  0
# random:        jump,run distance: 351 sys_reward:  0
# random:   Left+jump,run distance: 352 sys_reward:  0
# random:       Left+jump distance: 351 sys_reward:  0
# random:            jump distance: 350 sys_reward:  0
# random:            Left distance: 350 sys_reward:  0
# random:   Left+jump,run distance: 350 sys_reward:  0
# random:            Down distance: 350 sys_reward:  0
# random:            Left distance: 350 sys_reward:  0
# random:            Down distance: 350 sys_reward:  0
# random:  Right+jump,run distance: 351 sys_reward:  1
# random:            jump distance: 352 sys_reward:  0
# random:        jump,run distance: 352 sys_reward:  0
# random:        Left+run distance: 352 sys_reward:  0
# random:       Left+jump distance: 350 sys_reward: -1
# random:        Left+run distance: 350 sys_reward:  0
# random:            Nope distance: 350 sys_reward:  0
# random:              Up distance: 350 sys_reward:  0
# random:           Right distance: 351 sys_reward:  0
# random:        Left+run distance: 351 sys_reward: -1
# random:   Left+jump,run DONE!! final distance:  351
# distance: 351 sys_reward:  0
# last reward:  -1.0
# episode: 5 , epsilon:  0.9900990099009901
# random:        jump,run
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-ead6bb087c5e> in <module>()
#     236
#     237             for n in range(len(action)):
# --> 238                 next_state, reward, done, info = env.step(action[n])
#     239
#     240
#
# /usr/local/lib/python3.5/dist-packages/gym/core.py in step(self, action)
#      94             info (dict): contains auxiliary diagnostic information (helpful for debugging, and sometimes learning)
#      95         """
# ---> 96         return self._step(action)
#      97
#      98     def reset(self):
#
# /usr/local/lib/python3.5/dist-packages/gym/wrappers/monitoring.py in _step(self, action)
#      31     def _step(self, action):
#      32         self._before_step(action)
# ---> 33         observation, reward, done, info = self.env.step(action)
#      34         done = self._after_step(observation, reward, done, info)
#      35
#
# /usr/local/lib/python3.5/dist-packages/gym/core.py in step(self, action)
#      94             info (dict): contains auxiliary diagnostic information (helpful for debugging, and sometimes learning)
#      95         """
# ---> 96         return self._step(action)
#      97
#      98     def reset(self):
#
# /usr/local/lib/python3.5/dist-packages/gym/wrappers/time_limit.py in _step(self, action)
#      34     def _step(self, action):
#      35         assert self._episode_started_at is not None, "Cannot call env.step() before calling reset()"
# ---> 36         observation, reward, done, info = self.env.step(action)
#      37         self._elapsed_steps += 1
#      38
#
# /usr/local/lib/python3.5/dist-packages/gym/core.py in step(self, action)
#      94             info (dict): contains auxiliary diagnostic information (helpful for debugging, and sometimes learning)
#      95         """
# ---> 96         return self._step(action)
#      97
#      98     def reset(self):
#
# /usr/local/lib/python3.5/dist-packages/ppaquette_gym_super_mario/nes_env.py in _step(self, action)
#     318             while self.last_frame <= start_frame and not self.is_finished:
#     319                 loop_counter += 1
# --> 320                 sleep(0.001)
#     321                 if 0 == self.is_initialized:
#     322                     break
#
# KeyboardInterrupt:

# %%
info
# Out:
# {'coins': 0,
#  'distance': 40,
#  'level': 1,
#  'life': 3,
#  'player_status': 0,
#  'score': 0,
#  'time': 399}

# %%
rewad = -6
rewad = float(np.clip(rewad, -1,1))
rewad
# Out:
# -1.0

# %%
DISTANCE
# Out:
# [(1, 29), (2, 646)]

# %%
with open('DISTANCE', 'rb') as fp:
    dist = pickle.load(fp)

dist = np.array(dist)
dist = dist.T
plt.plot(dist[0], dist[1])
