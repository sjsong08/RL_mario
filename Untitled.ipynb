# %%
dist
# Out:
# array([[  1,   2,   3],
#        [ 70,  17, 141]])

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import time
# %matplotlib inline 


with open('DISTANCE', 'rb') as fp:
    dist = pickle.load(fp)

dist = np.array(dist)
dist = dist.T

fig = plt.figure(figsize=[10,6])
ax1 = fig.add_subplot(1,1,1)

ax1.plot(dist[0], dist[1], 'b')
ax1.set_xlabel('episode')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('distance', color='b')
#ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(dist[0], dist[2], 'r')
ax2.set_ylabel('epsilon', color='r')
#ax2.tick_params('y', colors='r')


plt.show()

# %%
time.sleep(1)

# %%
A=[]
A.append(1)
A.append(2)
A.append(3)
A.append(4)
A.append(5)
A.append(6)

[A[-2*k-2] for k in range(2)]
# Out:
# [5, 3]

# %%
np.median(A)
# Out:
# 3.5

# %%
k=2
pow(0.9,k)
# Out:
# 0.81
